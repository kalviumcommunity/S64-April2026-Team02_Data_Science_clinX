# %% [markdown]
# # Markdown Formatting and Documentation

# %% [markdown]
# ## Objective
#
# This notebook demonstrates the use of Markdown cells to improve readability, structure, and explanation in Jupyter notebooks.
#
# Markdown is used to explain **why** a step is being performed, while Code cells are used to show **what** is being executed.

# %% [markdown]
# ## Key Concepts Covered
#
# - Headings for notebook structure
# - Ordered and unordered lists
# - Inline code formatting
# - Code blocks in Markdown
# - Combining Markdown and Code cells
#
# ### Step-by-Step Flow
#
# 1. Explain the task
# 2. Execute the code
# 3. Interpret the result

# %% [markdown]
# ## Code Explanation
#
# The variable `x` stores a numerical value.
#
# The function `print()` is used to display output.
#
# Example code snippet:
#
# ```python
# x = 10
# print(x)

# %% [markdown]
# This is very important because the milestone explicitly asks for:
#
# - inline code
# - fenced code blocks
#
# ---
#
# # Cell 5 → Code cell
#
# Now add a Code cell:
#
# ```python id="97008"
# x = 10
# print("Value of x:", x)

# %% [markdown]
# ## Output Interpretation
#
# The above code assigns the value `10` to the variable `x` and displays it.
#
# This demonstrates how Markdown can be used **after code** to explain what the output means.

# %% [markdown]
# ## Next Step
#
# The following code demonstrates a simple addition operation.

# %%
a = 5
b = 7
print("Sum =", a + b)
# Out:
# Sum = 12

# %% [markdown]
# ### Result
#
# The sum of `a` and `b` is displayed as `12`.
#
# This structure keeps logic and explanation separate.
