# %% [markdown]
# # Milestone 3: Understanding Code and Markdown Cells

# %% [markdown]
# ## Purpose
#
# This notebook demonstrates the correct use of Code and Markdown cells in Jupyter Notebook.
#
# Markdown cells are used to explain the logic and structure of the notebook, while Code cells are used to execute Python commands.

# %%
print("Hello, Jupyter Notebook")

# %% [markdown]
# ### Explanation
#
# The above Code cell prints a simple message to verify that Python code executes successfully inside the notebook.

# %%
x = 10
y = 20
print("Sum =", x + y)

# %% [markdown]
# ### Output Explanation
#
# This Code cell defines two variables and calculates their sum.
#
# This demonstrates that Code cells are used for computation and output generation.
